# %%
import pandas as pd 
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
url=(r"C:\Users\war machine rocks\Downloads\Adidas Vs Nike.csv")

# %%
df1=pd.read_csv(url)

# %%
df1
# Out:
#                                            Product Name  Product ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing Price  Sale Price  Discount                    Brand  \
# 0             14999        7499        50  Adidas Adidas ORIGINALS
# ...

# %%
nike=df1.groupby('Brand').get_group('Nike')

# %%
nike
# Out:
#                               Product Name  Product ID  Listing Price  \
# 2625        Nike Air Force 1 '07 Essential  CJ1646-600              0
# 2626                  Nike Air Force 1 '07  CT4328-101              0
# 2627          Nike Air Force 1 Sage Low LX  CI3482-200              0
# 2628                   Nike Air Max Dia SE  CD0479-200              0
# 2629                   Nike Air Max Verona  CZ6156-101              0
# ...                                    ...         ...            ...
# 3263                    Air Jordan 8 Retro  CI1236-100          15995
# 3264            Nike Phantom Venom Club IC  AO0578-717           4995
# 3265  Nike Mercurial Superfly 7 Academy TF  AT7978-414           8495
# 3266                       Nike Air Max 98  AH6799-300              0
# 3267                        Nike P-6000 SE  CJ9585-600           8995
#
#       Sale Price  Discount Brand  \
# 2625        7495         0  Nike
# 2626        7495         0  Nike
# ...

# %%
adidas_variations = ['Adidas ORIGINALS','Adidas CORE / NEO','Adidas SPORT PERFORMANCE']

# %%
# Separate Adidas brand rows
adidas_rows = df1[df1['Brand'].isin(adidas_variations)]
nike_rows = df1[df1['Brand'] == 'Nike']

# %%
adidas=adidas_rows.select_dtypes(include=('int','float'))

# %%
nike=nike_rows.select_dtypes(include=('int','float'))
nike
# Out:
#       Listing Price  Sale Price  Discount  Rating  Reviews
# 2625              0        7495         0     0.0        0
# 2626              0        7495         0     0.0        0
# 2627              0        9995         0     0.0        0
# 2628              0        9995         0     0.0        0
# 2629              0        9995         0     0.0        0
# ...             ...         ...       ...     ...      ...
# 3263          15995       12797         0     5.0        1
# 3264           4995        3497         0     0.0        0
# 3265           8495        5947         0     5.0        1
# 3266              0       16995         0     4.0        4
# 3267           8995        6297         0     0.0        0
#
# [643 rows x 5 columns]

# %%
adidas=adidas.head(200)

# %%
nike=nike.head(200)

# %%
print(nike.columns)
# Out:
# Index(['Listing Price', 'Sale Price', 'Discount', 'Rating', 'Reviews'], dtype='object')

# %%
X=nike.drop(['Rating', 'Reviews'],axis=1)
y=nike[['Rating','Reviews']]
x
# Out:
#       Listing Price  Sale Price  Discount
# 2625              0        7495         0
# 2626              0        7495         0
# 2627              0        9995         0
# 2628              0        9995         0
# 2629              0        9995         0
# ...             ...         ...       ...
# 2820          15995       12797         0
# 2821              0       12995         0
# 2822           9995        7997         0
# 2823              0        9995         0
# 2824              0       18995         0
#
# [200 rows x 3 columns]

# %%
Nike_test,Nike_train,y_test,y_train=train_test_split(X,y,test_size=0.2,random_state=70)

# %%
sc=StandardScaler()
sc.fit(Nike_train)
# Out:
# StandardScaler()

# %%
sc.mean_
# Out:
# array([ 3657.28682171, 10070.06976744,     0.        ])

# %%
sc.scale_
# Out:
# array([5.6775839e+03, 4.3337255e+03, 1.0000000e+00])

# %%
Nike_train.describe()
# Out:
#        Listing Price    Sale Price  Discount
# count     129.000000    129.000000     129.0
# mean     3657.286822  10070.069767       0.0
# std      5699.718812   4350.621177       0.0
# min         0.000000   1595.000000       0.0
# 25%         0.000000   6495.000000       0.0
# 50%         0.000000   8997.000000       0.0
# 75%      7995.000000  12995.000000       0.0
# max     16995.000000  22995.000000       0.0

# %%
Nike_train=sc.transform(Nike_train)
Nike_test=sc.transform(Nike_test)

# %%
Nike_train=pd.DataFrame(Nike_train,columns = ['Listing Price','Sale Price','Discount'])
Nike_test=pd.DataFrame(Nike_test,columns = ['Listing Price','Sale Price','Discount'])

# %%
Nike_train
# Out:
#      Listing Price  Sale Price  Discount
# 0        -0.644163   -0.478819       0.0
# 1        -0.644163   -1.171064       0.0
# 2         0.940138   -0.662956       0.0
# 3        -0.644163    1.367168       0.0
# 4        -0.644163    0.213426       0.0
# ..             ...         ...       ...
# 124       0.235613   -1.516725       0.0
# 125      -0.644163    0.905671       0.0
# 126       1.116269   -0.709106       0.0
# 127      -0.644163   -0.940316       0.0
# 128      -0.644163   -0.248071       0.0
#
# [129 rows x 3 columns]

# %%
Nike_test
# Out:
#      Listing Price  Sale Price  Discount
# 0        -0.644163   -0.709567       0.0
# 1         1.644663   -0.524507       0.0
# 2        -0.644163   -1.055690       0.0
# 3        -0.644163   -0.709567       0.0
# 4        -0.644163   -0.017322       0.0
# ..             ...         ...       ...
# 509      -0.644163    0.213426       0.0
# 510      -0.644163   -0.571118       0.0
# 511       0.852073   -0.951392       0.0
# 512      -0.644163   -1.401812       0.0
# 513      -0.644163   -1.055690       0.0
#
# [514 rows x 3 columns]

# %%
Nike_train.round(2)
# Out:
#        0     1    2
# 0  -0.44 -0.72  0.0
# 1  -0.44  1.68  0.0
# 2  -0.44 -1.12  0.0
# 3   1.67 -0.72  0.0
# 4  -0.44 -1.52  0.0
# 5  -0.44 -0.72  0.0
# 6  -0.44 -0.99  0.0
# 7  -0.44  0.35  0.0
# 8  -0.44 -0.72  0.0
# 9  -0.44  0.88  0.0
# 10  1.25 -1.36  0.0
# 11 -0.44  0.08  0.0
# 12 -0.44 -0.86  0.0
# 13 -0.44  0.35  0.0
# 14  2.94  0.56  0.0
# 15 -0.44 -0.46  0.0
# 16  1.14 -1.46  0.0
# 17 -0.44  1.68  0.0
# 18 -0.44  1.68  0.0
# 19 -0.44 -0.59  0.0
# 20 -0.44  0.35  0.0
# 21 -0.44  1.42  0.0
# 22 -0.44  0.61  0.0
# 23  2.94  0.35  0.0
# 24 -0.44 -1.26  0.0
# 25 -0.44 -1.39  0.0
# 26 -0.44  1.42  0.0
# 27 -0.44  1.42  0.0
# 28 -0.44  0.35  0.0
# 29 -0.44 -0.72  0.0
# 30 -0.44 -0.05  0.0
# 31 -0.44 -0.19  0.0
# 32  2.51 -0.62  0.0
# 33 -0.44 -0.72  0.0
# 34 -0.44  1.15  0.0
# 35 -0.44  2.22  0.0
# 36 -0.44 -0.19  0.0
# 37  2.09 -0.29  0.0
# 38 -0.44 -0.19  0.0
# 39 -0.44  0.35  0.0

# %%
sns.pairplot(Nike_test)
